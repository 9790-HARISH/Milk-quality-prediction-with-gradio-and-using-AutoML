# %%
# !pip install pycaret

# %%
from pycaret.classification import *

# %%
import pandas as pd
import numpy as np
d = pd.read_csv('/content/MILK QUALITY DATASET (1).csv')

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
d['Grade']=l.fit_transform(d['Grade'])

# %%
a= setup(d, target='Grade')
# Out:
# <style type="text/css">
# #T_3b17b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3b17b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b17b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3b17b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b17b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b17b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3b17b_row0_col1" class="data row0 col1" >7182</td>
#     </tr>
#     <tr>
#       <th id="T_3b17b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b17b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3b17b_row1_col1" class="data row1 col1" >Grade</td>
#     </tr>
#     <tr>
#       <th id="T_3b17b_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_15552 th {
#   text-align: left;
# }
# ...

# %%
model=create_model(best_model)
# Out:
# <style type="text/css">
# #T_32b69_row10_col0, #T_32b69_row10_col1, #T_32b69_row10_col2, #T_32b69_row10_col3, #T_32b69_row10_col4, #T_32b69_row10_col5, #T_32b69_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_32b69" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32b69_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_32b69_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_32b69_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_32b69_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_32b69_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_32b69_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_32b69_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
pred=predict_model(model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_947a8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_947a8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_947a8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_947a8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_947a8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_947a8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_947a8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_947a8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_947a8_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_947a8_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
final_model=finalize_model(best_model)

# %%
pred=predict_model(final_model,data=d)
# Out:
# <style type="text/css">
# </style>
# <table id="T_475b3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_475b3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_475b3_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_475b3_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_475b3_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_475b3_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_475b3_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_475b3_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_475b3_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_475b3_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
from sklearn.metrics import accuracy_score as ac,classification_report  as cr,precision_score as ps,recall_score as rs

# %%
pred=best_model.predict()

# %%
ac(d['Grade'],pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-0ccd6bc04e5c> in <cell line: 1>()
# ----> 1 ac(d['Grade'],pred)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     211
#     212     # Compute accuracy for each possible representation
# --> 213     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     214     check_consistent_length(y_true, y_pred, sample_weight)
# ...

# %%
automl_model = automl(optimize='Accuracy')

# %%
#evaluate_model(automl_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
